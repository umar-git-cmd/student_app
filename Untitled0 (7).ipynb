# %%
import pandas as pd

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df = df.rename(columns={'race/ethnicity': 'race_ethnicity', 'parental level of education': 'parental_level_of_education', 'test preparation course': 'test_preparation_course', 'math score': 'math_score', 'reading score': 'reading_score', 'writing score': 'writing_score'})

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.to_csv('students_clean.csv', index=False)

# %%
df['race_ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['race_ethnicity'].nunique()
# Out:
# 5

# %%
df['math_score'].sort_values(ascending=False).head(3)
# Out:
# 451    100
# 458    100
# 962    100
# Name: math_score, dtype: int64

# %%
df.groupby('race_ethnicity')['math_score'].mean().round().sort_values(ascending=False).head(3)
# Out:
# race_ethnicity
# group E    74.0
# group D    67.0
# group C    64.0
# Name: math_score, dtype: float64

# %%
count_people = (df['test_preparation_course'] == 'completed').sum()
print(f'Студенты которые гототовились к экзамену: {count_people}')
# Out:
# Студенты которые гототовились к экзамену: 358

# %%
df[df['test_preparation_course'] == 'completed']
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 6    female        group B                some college      standard
# 8      male        group D                 high school  free/reduced
# 13     male        group A                some college      standard
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.groupby('test_preparation_course')['math_score'].mean().round()
# Out:
# test_preparation_course
# completed    70.0
# none         64.0
# Name: math_score, dtype: float64

# %%
df.groupby('lunch')['reading_score'].mean().round()
# Out:
# lunch
# free/reduced    65.0
# standard        72.0
# Name: reading_score, dtype: float64

# %%
df['parental_level_of_education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
(df['parental_level_of_education'] == "bachelor's degree").sum()
# Out:
# np.int64(118)

# %%
df[df['parental_level_of_education'] == "bachelor's degree"]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 24     male        group D           bachelor's degree  free/reduced
# 27   female        group C           bachelor's degree      standard
# 60     male        group E           bachelor's degree  free/reduced
# 77     male        group A           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 916    male        group E           bachelor's degree      standard
# 933    male        group C           bachelor's degree  free/reduced
# 969  female        group B           bachelor's degree      standard
# 970  female        group D           bachelor's degree      standard
# 993  female        group D           bachelor's degree  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
(df['gender'] == 'female').sum()
# Out:
# np.int64(518)

# %%
(df['gender'] == 'male').sum()
# Out:
# np.int64(482)

# %%
df['gender'].value_counts(normalize=True).round(2)
# Out:
# gender
# female    0.52
# male      0.48
# Name: proportion, dtype: float64

# %%
df.groupby('gender')['math_score'].mean().round()
# Out:
# gender
# female    64.0
# male      69.0
# Name: math_score, dtype: float64

# %%
df.groupby('gender')['reading_score'].mean().round()
# Out:
# gender
# female    73.0
# male      65.0
# Name: reading_score, dtype: float64

# %%
df.groupby('gender')['writing_score'].mean().round()
# Out:
# gender
# female    72.0
# male      63.0
# Name: writing_score, dtype: float64

# %%
df.groupby('gender')[['math_score', 'reading_score', 'writing_score']].mean().round()
# Out:
#         math_score  reading_score  writing_score
# gender
# female        64.0           73.0           72.0
# male          69.0           65.0           63.0

# %%
df['parental_level_of_education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
(df['parental_level_of_education'] == 'high school').sum()
# Out:
# np.int64(196)

# %%
df.groupby('parental_level_of_education')['math_score'].mean().round()
# answer: 62.0
# Out:
# parental_level_of_education
# associate's degree    68.0
# bachelor's degree     69.0
# high school           62.0
# master's degree       70.0
# some college          67.0
# some high school      63.0
# Name: math_score, dtype: float64

# %%
(df['math_score']  >= 90 ).sum()
# Out:
# np.int64(58)

# %%
df[(df['math_score'] > 80) &  (df['reading_score'] > 80) & (df['writing_score'] > 80)].shape[0]
# Out:
# 110

# %% [markdown]
# **Home Work 2:**

# %%
df.groupby('gender')['math_score'].mean().round()
# Out:
# gender
# female    64.0
# male      69.0
# Name: math_score, dtype: float64

# %%
df.groupby('gender')['reading_score'].mean().round()
# Out:
# gender
# female    73.0
# male      65.0
# Name: reading_score, dtype: float64

# %%
df.groupby('gender')[['math_score', 'reading_score', 'writing_score']].mean().round()
# Out:
#         math_score  reading_score  writing_score
# gender
# female        64.0           73.0           72.0
# male          69.0           65.0           63.0

# %%
df.groupby('gender')['writing_score'].median()
# Out:
# gender
# female    74.0
# male      64.0
# Name: writing_score, dtype: float64

# %%
df.groupby('parental_level_of_education')['math_score'].mean().round().sort_values(ascending=False)
# Out:
# parental_level_of_education
# master's degree       70.0
# bachelor's degree     69.0
# associate's degree    68.0
# some college          67.0
# some high school      63.0
# high school           62.0
# Name: math_score, dtype: float64

# %%
df.groupby(['test_preparation_course', 'lunch'])[['math_score', 'reading_score', 'writing_score']].mean().round()
# Out:
#                                       math_score  reading_score  writing_score
# test_preparation_course lunch
# completed               free/reduced        63.0           70.0           70.0
#                         standard            74.0           76.0           77.0
# none                    free/reduced        57.0           62.0           59.0
#                         standard            68.0           69.0           68.0

# %%
df['all_scores'] = df['math_score'] + df['reading_score'] + df['writing_score']

# %%
df['all_scores'].max()
# Out:
# 300

# %%
df[df['all_scores'] == 300]
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
#
#      all_scores
# 458         300
# 916         300
# 962         300

# %%
(df['math_score'] >= 90).sum()
# Out:
# np.int64(58)

# %%
(df['all_scores'] > 80).sum()
# Out:
# np.int64(994)

# %%
(df['math_score'] > 80) & (df['reading_score'] > 80) & (df['writing_score'] > 80)
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.groupby(['gender', 'race_ethnicity'])[['math_score', 'reading_score', 'writing_score']].mean()
# Out:
#                        math_score  reading_score  writing_score
# gender race_ethnicity
# female group A          58.527778      69.000000      67.861111
#        group B          61.403846      71.076923      70.048077
#        group C          62.033333      71.944444      71.777778
#        group D          65.248062      74.046512      75.023256
#        group E          70.811594      75.840580      75.536232
# male   group A          63.735849      61.735849      59.150943
#        group B          65.930233      62.848837      60.220930
#        group C          67.611511      65.424460      62.712230
#        group D          69.413534      66.135338      65.413534
#        group E          76.746479      70.295775      67.394366

# %%
df['average_score'] = (df['all_scores'] / 3).round()

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %% [markdown]
# **ГРАФИК ДЗ 2**: Seaborn, Matplotlib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='reading_score', bins=10, kde=True, color='red', hue='gender')
plt.title('График по math')
plt.xlabel('Баллы по mth')
plt.ylabel('Количество студентов')
plt.grid()
plt.savefig('math_score.png')
plt.show()

# %%
sns.histplot(data=df, x='average_score', binwidth=5)
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', bins=10, kde=True, color='red', hue='gender')
plt.title('График по math')
plt.xlabel('Баллы по mth')
plt.ylabel('Количество студентов')
plt.grid()
plt.savefig('math_score.png')
plt.show()

# %%
sns.boxplot(data=df, x='gender', y='math_score')
plt.show()

# %%
df.groupby('gender')['math_score'].describe().round()
# Out:
#         count  mean   std   min   25%   50%   75%    max
# gender
# female  518.0  64.0  15.0   0.0  54.0  65.0  74.0  100.0
# male    482.0  69.0  14.0  27.0  59.0  69.0  79.0  100.0

# %%
# HISTPLOT:
# MATH_SCORE SIMPLE

plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', bins=20, kde=True, color='green')
plt.title('chart')
plt.xlabel('math_score')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
# READING_SCORE SIMPLE
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='reading_score', kde=True, color='black')
plt.title('chart')
plt.xlabel('reading_score')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
# WRITING_SCORE SIMPLE
plt.figure(figsize=(6,4))
sns.histplot(data=df, x='writing_score', kde=True, color='pink')
plt.title('chart')
plt.xlabel('writing_score')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
# MATH_SCORE (GENDER, RACE, TEST, LUNCH, PARENTAL)
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', color='red', kde=True, hue='gender')
plt.title('chart')
plt.xlabel('баллы')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', color='red', kde=True, hue='race_ethnicity')
plt.title('chart')
plt.xlabel('баллы')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', color='red', kde=True, hue='test_preparation_course')
plt.title('chart')
plt.xlabel('баллы')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', color='red', kde=True, hue='lunch')
plt.title('chart')
plt.xlabel('баллы')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.histplot(data=df, x='math_score', color='red', kde=True, hue='parental_level_of_education')
plt.title('chart')
plt.xlabel('баллы')
plt.ylabel('quantity')
plt.grid()
plt.show()

# %%
# BOXPLOT:
# MATH_SCORE (GENDER, RACE, TEST, LUNCH, PARENTAL)
sns.boxplot(data=df, x='gender', y='math_score')
plt.show()

# %%
sns.boxplot(data=df, x='race_ethnicity', y='math_score')
plt.show()

# %%
sns.boxplot(data=df, x='test_preparation_course', y='math_score')
plt.show()

# %%
sns.boxplot(data=df, x='lunch', y='math_score')
plt.show()

# %%
sns.boxplot(data=df, x='parental_level_of_education', y='math_score')
plt.show()

# %%
sns.boxplot(data=df, x='gender', y='reading_score')
plt.show()

# %%
sns.boxplot(data=df, x='race_ethnicity', y='reading_score')
plt.show()

# %%
sns.boxplot(data=df, x='test_preparation_course', y='reading_score')
plt.show()

# %%
sns.boxplot(data=df, x='lunch', y='reading_score')
plt.show()

# %%
sns.boxplot(data=df, x='parental_level_of_education', y='reading_score')
plt.show()

# %%
# WRITING_SCORE (GENDER, RACE, TEST, LUNCH, PARENTAL)
sns.boxplot(data=df, y='writing_score', x='gender')
plt.show()

# %%
sns.boxplot(data=df, y='writing_score', x='race_ethnicity')
plt.show()

# %%
sns.boxplot(data=df, y='writing_score', x='test_preparation_course')
plt.show()

# %%
sns.boxplot(data=df, y='writing_score', x='lunch')
plt.show()

# %%
sns.boxplot(data=df, y='writing_score', x='parental_level_of_education')
plt.show()

# %%
sns.violinplot(data=df, x='race_ethnicity', y='writing_score', hue='gender', split=True)
plt.show()

# %%
df.groupby(['race_ethnicity', 'writing_score'])['gender'].describe().round()
# Out:
#                              count unique     top freq
# race_ethnicity writing_score
# group A        19                1      1    male    1
#                34                1      1    male    1
#                36                1      1    male    1
#                41                2      2    male    1
#                43                5      2    male    4
# ...                            ...    ...     ...  ...
# group E        93                2      2    male    1
#                94                1      1  female    1
#                95                3      1  female    3
#                97                1      1  female    1
#                100               6      2  female    5
#
# [286 rows x 4 columns]

# %%
sns.barplot(data=df, y='parental_level_of_education', x='math_score')
plt.show()

# %%
df.groupby('parental_level_of_education')['math_score'].mean().round()
# Out:
# parental_level_of_education
# associate's degree    68.0
# bachelor's degree     69.0
# high school           62.0
# master's degree       70.0
# some college          67.0
# some high school      63.0
# Name: math_score, dtype: float64

# %%
# MATH_SCORE (GENDER, RACE, TEST, LUNCH, PARENTAL)

sns.violinplot(data=df, x='gender', y='math_score')
plt.show()

# %%
sns.violinplot(data=df, x='race_ethnicity', y='writing_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='test_preparation_course', y='writing_score', hue='gender', split=True)
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='writing_score'>

# %%
sns.violinplot(data=df, x='lunch', y='writing_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='parental_level_of_education', y='writing_score', hue='gender', split=True)
plt.show()

# %%
# READING_SCORE (GENDER, RACE, TEST, LUNCH, PARENTAL)
sns.violinplot(data=df, x='gender', y='reading_score')
plt.show()

# %%
sns.violinplot(data=df, x='race_ethnicity', y='reading_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='test_preparation_course', y='reading_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='lunch', y='reading_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='parental_level_of_education', y='reading_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='gender', y='writing_score')
plt.show()

# %%
sns.violinplot(data=df, x='race_ethnicity', y='writing_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='test_preparation_course', y='writing_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='lunch', y='writing_score', hue='gender', split=True)
plt.show()

# %%
sns.violinplot(data=df, x='parental_level_of_education', y='writing_score', hue='gender', split=True)
plt.show()

# %%
df = df.drop(columns=['all_scores', 'average_score'])

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df = pd.get_dummies(df, columns=['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch', 'test_preparation_course'], drop_first=True).astype(int)

# %%
df
# Out:
#      math_score  reading_score  writing_score  gender_male  \
# 0            72             72             74            0
# 1            69             90             88            0
# 2            90             95             93            0
# 3            47             57             44            1
# 4            76             78             75            1
# ..          ...            ...            ...          ...
# 995          88             99             95            0
# 996          62             55             55            1
# 997          59             71             65            0
# 998          68             78             77            0
# 999          77             86             86            0
#
#      race_ethnicity_group B  race_ethnicity_group C  race_ethnicity_group D  \
# 0                         1                       0                       0
# 1                         0                       1                       0
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df.drop(columns='writing_score'))

# %%
scaled_data
# Out:
# array([[ 0.39002351,  0.19399858, -0.96462528, ..., -0.4669334 ,
#          0.74188112,  0.74674788],
#        [ 0.19207553,  1.42747598, -0.96462528, ..., -0.4669334 ,
#          0.74188112, -1.33914006],
#        [ 1.57771141,  1.77010859, -0.96462528, ..., -0.4669334 ,
#          0.74188112,  0.74674788],
#        ...,
#        [-0.46775108,  0.12547206, -0.96462528, ..., -0.4669334 ,
#         -1.34792485, -1.33914006],
#        [ 0.12609287,  0.60515772, -0.96462528, ..., -0.4669334 ,
#          0.74188112, -1.33914006],
#        [ 0.71993682,  1.15336989, -0.96462528, ..., -0.4669334 ,
#         -1.34792485,  0.74674788]])

# %%
x = scaled_data
y = df['writing_score']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lin_model = LinearRegression()

# %%
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = lin_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_predict, y_test)
# Out:
# 0.9344772753176349

# %%
import joblib

joblib.dump(lin_model, 'model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
df.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score', 'gender_male',
#        'race_ethnicity_group B', 'race_ethnicity_group C',
#        'race_ethnicity_group D', 'race_ethnicity_group E',
#        'parental_level_of_education_bachelor's degree',
#        'parental_level_of_education_high school',
#        'parental_level_of_education_master's degree',
#        'parental_level_of_education_some college',
#        'parental_level_of_education_some high school', 'lunch_standard',
#        'test_preparation_course_none'],
#       dtype='object')
